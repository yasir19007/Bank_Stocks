# %% [markdown]
# # Finance Data Project
#
# In this data project we will focus on exploratory data analysis of stock prices. Keep in mind, this project is just meant to practice visualization and pandas skills, it is not meant to be a robust financial analysis or be taken as financial advice.
# ____
# We'll focus on bank stocks and see how they progressed throughout the [financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to early 2016.

# %% [markdown]
# ## Get the Data
#
# In this section we will learn how to use pandas to directly read data from Google finance using pandas!
#
# First we need to start with the proper imports, which we've already laid out for you here.
#
# ### The Imports

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Data
#
# We need to get data using pandas datareader. We will get stock information for the following banks:
# *  Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# ** Figure out how to get the stock data from Jan 1st 2006 to Jan 1st 2016 for each of these banks. Set each bank to be a separate dataframe, with the variable name for that bank being its ticker symbol. This will involve a few steps:**
# 1. Use datetime to set start and end datetime objects.
# 2. Figure out the ticker symbol for each bank.
# 2. Figure out how to use datareader to grab info on the stock.
#
#
#     # Bank of America
#     BAC = data.DataReader("BAC", 'google', start, end)
#
# ------------

# %%
start = datetime.datetime(2006, 1, 1)

end   = datetime.datetime(2016, 1, 1)

# %%
import yfinance as yf

# Bank of America
BAC = yf.Ticker('BAC')

BACdata = BAC.history(start=start, end=end)

# %%
BACdata.head()
# Out:
#                                 Open       High        Low      Close
# Date
# 2006-01-03 00:00:00-05:00  32.584542  32.765106  32.049802  32.695660  \
# 2006-01-04 00:00:00-05:00  32.640084  32.806758  32.258126  32.348408
# 2006-01-05 00:00:00-05:00  32.348413  32.522030  32.167849  32.390079
# 2006-01-06 00:00:00-05:00  32.501212  32.577604  32.188700  32.341484
# 2006-01-09 00:00:00-05:00  32.445654  32.619272  32.195645  32.362316
#
#                              Volume  Dividends  Stock Splits
# Date
# 2006-01-03 00:00:00-05:00  16296700        0.0           0.0
# 2006-01-04 00:00:00-05:00  17757900        0.0           0.0
# 2006-01-05 00:00:00-05:00  14970700        0.0           0.0
# 2006-01-06 00:00:00-05:00  12599800        0.0           0.0
# 2006-01-09 00:00:00-05:00  15619400        0.0           0.0

# %%
#  Citigroup
C = yf.Ticker('C')
Cdata = C.history(start=start, end=end)

# Goldman Sachs
GS = yf.Ticker('GS')
GSdata = GS.history(start=start, end=end)

# JPmorgan Chase
JPM = yf.Ticker('GS')
JPMdata = JPM.history(start=start, end=end)

#  Morgan Stanley
MS = yf.Ticker('MS')
Msdata = MS.history(start=start, end=end)

#  Wells Fargo
WFC = yf.Ticker('WFC')
WFCdata = WFC.history(start=start, end=end)

# %% [markdown]
# ** Create a list of the ticker symbols (as strings) in alphabetical order. Call this list: tickers**

# %%
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

tickers
# Out:
# ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %% [markdown]
# ** Use pd.concat to concatenate the bank dataframes together to a single data frame called bank_stocks. Set the keys argument equal to the tickers list. Also pay attention to what axis you concatenate on.**

# %%
bank_stocks = pd.concat([BACdata, Cdata, GSdata, JPMdata, Msdata, WFCdata], 
                        axis=1, keys=tickers)
bank_stocks.head(2)
# Out:
#                                  BAC
#                                 Open       High        Low      Close
# Date
# 2006-01-03 00:00:00-05:00  32.584542  32.765106  32.049802  32.695660  \
# 2006-01-04 00:00:00-05:00  32.640084  32.806758  32.258126  32.348408
#
#                                                                      C
#                              Volume Dividends Stock Splits        Open
# Date
# 2006-01-03 00:00:00-05:00  16296700       0.0          0.0  344.733973  \
# 2006-01-04 00:00:00-05:00  17757900       0.0          0.0  343.749100
#
#                                                    ...       MS
#                                  High         Low  ...   Volume Dividends
# Date                                               ...
# 2006-01-03 00:00:00-05:00  347.407412  338.472483  ...  5377000       0.0  \
# 2006-01-04 00:00:00-05:00  345.437589  340.161048  ...  7977800       0.0
#
#                                               WFC
# ...

# %% [markdown]
# ** Set the column name levels (this is filled out for you):**

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %% [markdown]
# ** Check the head of the bank_stocks dataframe.**

# %%
bank_stocks.head(3)
# Out:
# Bank Ticker                      BAC
# Stock Info                      Open       High        Low      Close
# Date
# 2006-01-03 00:00:00-05:00  32.584542  32.765106  32.049802  32.695660  \
# 2006-01-04 00:00:00-05:00  32.640084  32.806758  32.258126  32.348408
# 2006-01-05 00:00:00-05:00  32.348413  32.522030  32.167849  32.390079
#
# Bank Ticker                                                          C
# Stock Info                   Volume Dividends Stock Splits        Open
# Date
# 2006-01-03 00:00:00-05:00  16296700       0.0          0.0  344.733973  \
# 2006-01-04 00:00:00-05:00  17757900       0.0          0.0  343.749100
# 2006-01-05 00:00:00-05:00  14970700       0.0          0.0  340.794255
#
# Bank Ticker                                        ...       MS
# Stock Info                       High         Low  ...   Volume Dividends
# Date                                               ...
# 2006-01-03 00:00:00-05:00  347.407412  338.472483  ...  5377000       0.0  \
# ...

# %% [markdown]
# # EDA
#
# Let's explore the data a bit! Before continuing, I encourage you to check out the documentation on [Multi-Level Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html) and [Using .xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html).
# Reference the solutions if you can not figure out how to use .xs(), since that will be a major part of this project.
#
# ** What is the max Close price for each bank's stock throughout the time period?**

# %%
# First Method

# for tick in tickers:  
#    print(tick, bank_stocks[tick]['Close'].max())

# Second Method

bank_stocks.xs(key='Close', axis=1, level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     39.540169
# C      413.428986
# GS     194.711487
# JPM    194.711609
# MS      53.785290
# WFC     46.429886
# dtype: float64

# %% [markdown]
# ** Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns = pd.DataFrame()

# %% [markdown]
# ** We can use pandas pct_change() method on the Close column to create a column representing this return value. Create a for loop that goes and for each Bank Stock Ticker creates this returns column and set's it as a column in the returns DataFrame.**

# %%
for tick in tickers:
    returns[tick + ' Return'] = bank_stocks[tick]['Close'].pct_change()

returns.head()
# Out:
#                            BAC Return  C Return  GS Return  JPM Return
# Date
# 2006-01-03 00:00:00-05:00         NaN       NaN        NaN         NaN  \
# 2006-01-04 00:00:00-05:00   -0.010621 -0.018462  -0.013812   -0.013812
# 2006-01-05 00:00:00-05:00    0.001288  0.004961  -0.000394   -0.000394
# 2006-01-06 00:00:00-05:00   -0.001500  0.000000   0.014169    0.014169
# 2006-01-09 00:00:00-05:00    0.000644 -0.004731   0.012031    0.012031
#
#                            MS Return  WFC Return
# Date
# 2006-01-03 00:00:00-05:00        NaN         NaN
# 2006-01-04 00:00:00-05:00   0.000686   -0.011599
# 2006-01-05 00:00:00-05:00   0.002742   -0.001110
# 2006-01-06 00:00:00-05:00   0.001026    0.005874
# 2006-01-09 00:00:00-05:00   0.010586   -0.000158

# %% [markdown]
# ** Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Can you figure out why?**

# %%
sns.pairplot(returns[1:])

# %% [markdown]
# * See solution for details about Citigroup behavior....

# %% [markdown]
# ** Using this returns DataFrame, figure out on what dates each bank stock had the best and worst single day returns. You should notice that 4 of the banks share the same day for the worst drop, did anything significant happen that day?**

# %%
returns.idxmin()
# Out:
# BAC Return   2009-01-20 00:00:00-05:00
# C Return     2009-02-27 00:00:00-05:00
# GS Return    2009-01-20 00:00:00-05:00
# JPM Return   2009-01-20 00:00:00-05:00
# MS Return    2008-10-09 00:00:00-04:00
# WFC Return   2009-01-20 00:00:00-05:00
# dtype: datetime64[ns, America/New_York]

# %%
returns.idxmax()
# Out:
# BAC Return   2009-04-09 00:00:00-04:00
# C Return     2008-11-24 00:00:00-05:00
# GS Return    2008-11-24 00:00:00-05:00
# JPM Return   2008-11-24 00:00:00-05:00
# MS Return    2008-10-13 00:00:00-04:00
# WFC Return   2008-07-16 00:00:00-04:00
# dtype: datetime64[ns, America/New_York]

# %% [markdown]
# ** You should have noticed that Citigroup's largest drop and biggest gain were very close to one another, did anythign significant happen in that time frame? **

# %% [markdown]
# * See Solution for details

# %% [markdown]
# ** Take a look at the standard deviation of the returns, which stock would you classify as the riskiest over the entire time period? Which would you classify as the riskiest for the year 2015?**

# %%
returns.std()
# Out:
# BAC Return    0.036659
# C Return      0.038672
# GS Return     0.025386
# JPM Return    0.025386
# MS Return     0.037717
# WFC Return    0.030195
# dtype: float64

# %%
returns.loc['2015-01-01' : '2015-12-31'].std()
# Out:
# BAC Return    0.016174
# C Return      0.015288
# GS Return     0.014043
# JPM Return    0.014043
# MS Return     0.016287
# WFC Return    0.012552
# dtype: float64

# %% [markdown]
# ** Create a distplot using seaborn of the 2015 returns for Morgan Stanley **

# %%
sns.displot(returns.loc['2015-01-01' : '2015-12-31']['MS Return'], color='green', bins=40)

# %% [markdown]
# ** Create a distplot using seaborn of the 2008 returns for CitiGroup **

# %%
sns.distplot(returns.loc['2008-01-01' : '2008-12-31']['C Return'], color='red', bins=50)
# Out:
# C:\Users\yasir\AppData\Local\Temp\ipykernel_10800\3632279391.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: xlabel='C Return', ylabel='Density'>

# %% [markdown]
# ____
# # More Visualization
#
# A lot of this project will focus on visualizations. Feel free to use any of your preferred visualization libraries to try to recreate the described plots below, seaborn, matplotlib, plotly and cufflinks, or just pandas.
#
# ### Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ** Create a line plot showing Close price for each bank for the entire index of time. (Hint: Try using a for loop, or use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) to get a cross section of the data.)**

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(label=tick, figsize=(18, 4))

plt.legend()

# %%
bank_stocks.xs(key='Close', axis=1, level='Stock Info').plot(figsize=(18, 6))
# Out:
# <Axes: xlabel='Date'>

# %%
bank_stocks.xs(key='Close', axis=1, level='Stock Info').iplot()
# Out:
# <div>                            <div id="7b92ce70-6380-4d51-86b6-6c8e6665bffa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## Moving Averages
#
# Let's analyze the moving averages for these stocks in the year 2008.
#
# ** Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %%
plt.figure(figsize=(18, 5))

BACdata['Close'].loc['2008-01-01' : '2009-01-01'].rolling(window=30).mean().plot(label="30 days mov avg")

BACdata['Close'].loc['2008-01-01' : '2009-01-01'].plot(label='BAC Close')

plt.legend()

# %% [markdown]
# ** Create a heatmap of the correlation between the stocks Close Price.**

# %%
sns.heatmap(bank_stocks.xs(key = 'Close', axis=1, level='Stock Info').corr(), annot=True)
# Out:
# <Axes: xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %% [markdown]
# ** Optional: Use seaborn's clustermap to cluster the correlations together:**

# %%
sns.clustermap(bank_stocks.xs(key = 'Close', axis=1, level='Stock Info').corr())

# %%
close_corr = bank_stocks.xs(key = 'Close', axis=1, level='Stock Info').corr()

close_corr.iplot(kind='heatmap', colorscale='rdylbu')
# Out:
# <div>                            <div id="e5a47c7b-9698-4984-8a80-0723db3159ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Part 2
#
# In this second part of the project we will rely on the cufflinks library to create some Technical Analysis plots.

# %% [markdown]
# ** Use .iplot(kind='candle) to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.**

# %%
bac15 = BACdata[['Open', 'High', 'Low', 'Close']].loc['2015-01-01' : '2016-01-01']

bac15.iplot(kind='candle')
# Out:
# <div>                            <div id="9ca7daab-fb88-4f71-9bbc-f4efb5aa74d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ** Use .ta_plot(study='sma') to create a Simple Moving Averages plot of Morgan Stanley for the year 2015.**

# %%
Msdata['Close'].loc['2015-01-01' : '2016-01-01'].ta_plot(study='sma', periods=[13, 21, 55])
# Out:
# <div>                            <div id="47ae5918-0cf5-4169-a7ed-fa515c52caba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# **Use .ta_plot(study='boll') to create a Bollinger Band Plot for Bank of America for the year 2015.**

# %%
BACdata['Close'].loc['2015-01-01' : '2016-01-01'].ta_plot(study='boll')
# Out:
# <div>                            <div id="16d8f0a4-c590-4939-a8b7-4a069b6e75a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
